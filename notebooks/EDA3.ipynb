# %%
#!pip install jq

# %%
import json
from pathlib import Path
import pandas as pd
from pprint import pprint
from langchain_community.document_loaders import JSONLoader
# Out:
# /Users/arindam/Machine Learning/GitHub_Repository/ShopChatApp/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
csv_file_path = "../artifacts/generated/dataset.csv"
json_file_path = "../artifacts/generated/dataset.json"

# %%
csv_file = pd.read_csv(csv_file_path)

# %%
csv_file[csv_file.duplicated(subset=['item_id'], keep='last')]
# Out:
#           item_id                      product_type country  marketplace  \
# 242    B01MXI65RV            [{'value': 'GROCERY'}]      US     AmazonGo
# 487    B07KCSH6RS            [{'value': 'GROCERY'}]      US     AmazonGo
# 842    B00U8QGU32  [{'value': 'HOME_BED_AND_BATH'}]      US       Amazon
# 858    B07VJGWWMM            [{'value': 'GROCERY'}]      US  AmazonFresh
# 934    B07DDPQ1HZ    [{'value': 'COMPUTER_ADD_ON'}]      US     AmazonGo
# ...           ...                               ...     ...          ...
# 19916  B074H5J2YW            [{'value': 'GROCERY'}]      US     AmazonGo
# 20634  B06XCTTF6S            [{'value': 'GROCERY'}]      US     PrimeNow
# 21290  B07WTS1P21            [{'value': 'GROCERY'}]      US     AmazonGo
# 21355  B074VDJ7KZ            [{'value': 'GROCERY'}]      US     AmazonGo
# 23396  B078ZM82H9             [{'value': 'COFFEE'}]      US       Amazon
#
#                domain_name                                     other_image_id  \
# ...

# %%
csv_file[csv_file.duplicated(subset=['item_id'], keep='last')]
# Out:
#           item_id                      product_type country  marketplace  \
# 242    B01MXI65RV            [{'value': 'GROCERY'}]      US     AmazonGo
# 487    B07KCSH6RS            [{'value': 'GROCERY'}]      US     AmazonGo
# 842    B00U8QGU32  [{'value': 'HOME_BED_AND_BATH'}]      US       Amazon
# 858    B07VJGWWMM            [{'value': 'GROCERY'}]      US  AmazonFresh
# 934    B07DDPQ1HZ    [{'value': 'COMPUTER_ADD_ON'}]      US     AmazonGo
# ...           ...                               ...     ...          ...
# 19916  B074H5J2YW            [{'value': 'GROCERY'}]      US     AmazonGo
# 20634  B06XCTTF6S            [{'value': 'GROCERY'}]      US     PrimeNow
# 21290  B07WTS1P21            [{'value': 'GROCERY'}]      US     AmazonGo
# 21355  B074VDJ7KZ            [{'value': 'GROCERY'}]      US     AmazonGo
# 23396  B078ZM82H9             [{'value': 'COFFEE'}]      US       Amazon
#
#                domain_name                                     other_image_id  \
# ...

# %%
csv_file.drop_duplicates(subset=['item_id'], keep='first', inplace=True)

# %%
# def csv_to_json(csv_file_path, json_file_path):
#     with open(csv_file_path, 'r') as csv_file, open(json_file_path, 'w') as json_file:
#         csv_reader = csv.DictReader(csv_file) # Read CSV as dictionaries
#         for row in csv_reader:
#             json.dump(row, json_file) # Write each row as JSON
#             json_file.write('\n') # Add newline for separation

# # Example usage
# csv_to_json(csv_file_path, 'json_file_path')

# %%
loader = JSONLoader(file_path=json_file_path, jq_schema=".[]", text_content=False)
documents = loader.load()

# %%
len(documents)
# Out:
# 26296

# %%
documents
# Out:
# [Document(page_content='{"item_id": "B073ZTQ44Y", "product_type": [{"value": "GROCERY"}], "country": "US", "marketplace": "Amazon", "domain_name": "amazon.com", "other_image_id": ["81laSOjKLwL", "61g2DDPfZHL", "51M39MBAwDL", "31C6QBNw8YL", "719ZZw6xiKL"], "spin_id": null, "3dmodel_id": null, "color_code": null, "brand_in_en_us": "Wickedly Prime", "bullet_point_in_en_us": "One 11.75-ounce pastic squeeze bottle", "color_in_en_us": null, "fabric_type_in_en_us": null, "finish_type_in_en_us": null, "item_keywords_in_en_us": "mustard", "item_name_in_en_us": "Wickedly Prime Mustard, White Wine Jalapeno, 11.75 Ounce", "item_shape_in_en_us": null, "material_in_en_us": null, "model_name_in_en_us": null, "pattern_in_en_us": null, "product_description_in_en_us": null, "height": 1635, "width": 930, "path": "83/83222ad0.jpg"}', metadata={'source': '/Users/arindam/Machine Learning/GitHub_Repository/ShopChatApp/artifacts/generated/dataset.json', 'seq_num': 1}),
# ...
